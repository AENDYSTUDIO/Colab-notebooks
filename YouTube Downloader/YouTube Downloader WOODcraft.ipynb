# %% [markdown]
# <a href="https://colab.research.google.com/github/AENDYSTUDIO/Colab-notebooks/blob/main/YouTube%20Downloader/YouTube%20Downloader%20WOODcraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color=GREEN size=4><b>[𝐖𝐎𝐎𝐃𝐜𝐫𝐚𝐟𝐭](https://t.me/Farooq_is_KING)</b></font>
# <!-- RAINBOW LINE TOP -->
# <center><img src="https://github.com/SudoR2spr/SudoR2spr/raw/main/assets/line-neon.gif" width="100%">
#
# <!-- GIF HEADER -->
# <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/Yt-dlp-angel.png" alt="MEGA Logo" height="150"></center>
# <img src="https://github.com/SudoR2spr/SudoR2spr/raw/main/assets/line-neon.gif" width="100%">
#
#
# [![Typing SVG](https://readme-typing-svg.herokuapp.com?font=Fira+Code&pause=1000&color=4250F7&background=FF512800&center=true&vCenter=true&width=435&lines=%F0%9D%90%96%F0%9D%90%8E%F0%9D%90%8E%F0%9D%90%83%F0%9D%90%9C%F0%9D%90%AB%F0%9D%90%9A%F0%9D%90%9F%F0%9D%90%AD+%F0%9D%90%8C%F0%9D%90%A2%F0%9D%90%AB%F0%9D%90%AB%F0%9D%90%A8%F0%9D%90%AB+%F0%9D%90%99%F0%9D%90%A8%F0%9D%90%A7%F0%9D%90%9E%E2%84%A2)](https://git.io/typing-svg)</p></center>

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/Angel-ji.png" alt="WD Logo" height="150"></center>
# <center><b>WOODcraft</b> By YouTube downloader</center>

# %% [markdown]
# ---
#
#
# #### <fornt><b>🔧 Google Drive<font color=Green size=4><b> 🔗 Connect</b></font>
#
# ---

# %%
# @markdown <font color=Green size=4><b>🔗 Mount Google Drive</b></font>
# @markdown <p>📂 Run this if you want to transfer your files to your google drive Gdrive.</p>
# @markdown <center><img src="https://raw.githubusercontent.com/SudoR2spr/GoFile-Downloader/main/Op%20Source/logo/gdrive.png" alt="Drive logo" height="50"></center>

import os
delete_path = '/content/sample_data'
if os.path.exists(delete_path):
    # !rm -rf '/content/sample_data'

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
#
# #### <font color=Green size=4><b>🔧 You can install ffmpeg</b></font>
#
# ---

# %%
# ffmpeg python package
# !apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %% [markdown]
# ---
#
#
# ####<font color=Red size=4><b>🔗  You can install yt-dlp</b></font>
#
# ---

# %%
# You can install yt-dlp using
# !pip install yt_dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 65.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ---
#
#
# #### <font color=Red size=4><b>🔧 🎬 YouTube downloader</b></font>
#
#
# ---

# %%
# @markdown <font color=Red size=4><b>🎬 YouTube downloader</b></font>
# @markdown <center><img src="https://raw.githubusercontent.com/SudoR2spr/SudoR2spr/main/assets/angel-op/Yt-dlp-angel.png" alt="yt-dlp logo" height="90"></center>
# @markdown <p>⬤ Use <b>YouTube Playlist and single link</b> Direct will download your Google drive, Folder Name is <b>YouTube video</b></p>
#URL = "" # @param {type:"string"}
#video_url = https://youtu.be/lyZ4EPre81s?si=fdp_uShL5RSP2aO7 # @param {type:"string"})
OUTPUT_PATH = "/content/drive/My Drive/Youtube video" # @param {type:"string"}

import yt_dlp
import os


ydl_opts = {
    'outtmpl': os.path.join(OUTPUT_PATH, '%(uploader)s/%(title)s.%(ext)s'),
    '-f': 'best',
    'parse-metadata': "%(series)s S%(season_number)02dE%(episode_number)02d:%(title)s",
    'vcodec': 'h264',
    'replace-in-metadata': "title,uploader" "[ angel_]" "-",
}


def download_video(url):
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

print(".")

banner = '''
█░█░█ █▀█ █▀█ █▀▄ █▀▀ █▀█ ▄▀█ █▀▀ ▀█▀
▀▄▀▄▀ █▄█ █▄█ █▄▀ █▄▄ █▀▄ █▀█ █▀░ ░█░'''

print(banner)


if __name__ == '__main__':
    video_url = input("🎬 𝐄𝐧𝐭𝐞𝐫 𝐓𝐡𝐞 𝐘𝐨𝐮𝐭𝐮𝐛𝐞 𝐕𝐢𝐝𝐞𝐨 𝐋𝐢𝐧𝐤 > 🔗 ")
    download_video (video_url)
    print(".")
    print("✅ 𝐒𝐮𝐜𝐜𝐞𝐬𝐬𝐟𝐮𝐥𝐥𝐲 𝐃𝐨𝐧𝐞..." "https://drive.google.com/drive/my-drive")
# Out:
# .
#
# █░█░█ █▀█ █▀█ █▀▄ █▀▀ █▀█ ▄▀█ █▀▀ ▀█▀
# ▀▄▀▄▀ █▄█ █▄█ █▄▀ █▄▄ █▀▄ █▀█ █▀░ ░█░

# %% [markdown]
# ---
#
#
# <center><fornt><b>🔧 ⎔〓 ᑭᵒʷᵉʳᵉᵈ • ᵇʸ 〓⎔ <font color=Green size=4><b> 🔗 𝐖𝐎𝐎𝐃𝐜𝐫𝐚𝐟𝐭</b></font></center>
#
# ---
